# %%
import pandas as pd

# %%
df = pd.read_excel(io='OJT.xls', 
                   sheet_name='공공데이터',
                   usecols='B:C',
                   names = ['RCP_PARTS_DTLS', '레시피명'])
df.head(20)
# Out:
#                                        RCP_PARTS_DTLS                레시피명
# 0   고구마죽\n고구마 100g(2/3개), 설탕 2g(1/3작은술), 찹쌀가루 3g(2...          칼륨 듬뿍 고구마죽
# 1   채소준비\n애호박 30g(1/6개), 표고버섯 20g(2개), 당근 5g(3×2×1...          누룽지 두부 계란죽
# 2   초밥\n밥 210g(1공기)\n배합초\n식초 20g(1⅓큰술), 설탕 10g(2작은...            오색지라시 스시
# 3   두부 곤약잡곡밥\n두부 110g(⅓모), 흰쌀 15g, 현미쌀 3g, 찹쌀 3g, ...        두부 곤약 나물 비빔밥
# 4   흑미밥\n쌀 90g, 검은 쌀 10g\n닭가슴살 삶기\n닭가슴살 40g(1/3개),...  저염 간장을 이용한 닭개장 비빔밥
# 5   취나물밥\n밥 210g(1공기), 다진 쇠고기 20g(1⅓큰술), 취나물 20g(8...    취나물 비빔밥 & 청국장 쌈장
# 6   잡곡밥\n잡곡밥 140g(2/3공기)\n곰취쌈\n곰취 30g, 소금 약간\n해물채소...    해물 채소장을 넣은 곰취 쌈밥
# 7   단호박찰밥\n찹쌀 100g, 밤 30g(3개), 은행 20g(8알), 잣 10g(1...             단호박 케일밥
# 8   영양밥\n찹쌀 100g, 흑미30g, 바지락 50g(16개), 강낭콩 15g(1큰술...             오색영양밥 롤
# 9   새우두부계란찜\n연두부 75g(3/4모), 칵테일새우 20g(5마리), 달걀 30g...           새우 두부 계란찜
# 10  부추 콩가루 찜\n조선부추 50g, 날콩가루 7g(1⅓작은술)\n양념장\n저염간장 ...            부추 콩가루 찜
# 11  연근 손질\n물 200ml(1컵), 식초 15g(1큰술)\n연근 구기자 물김치\n동...          연근 구기자 물김치
# ...

# %%
res = df["RCP_PARTS_DTLS"].str.split(pat = "\n")
res.head(20)
# Out:
# 0     [고구마죽, 고구마 100g(2/3개), 설탕 2g(1/3작은술), 찹쌀가루 3g(...
# 1     [채소준비, 애호박 30g(1/6개), 표고버섯 20g(2개), 당근 5g(3×2×...
# 2     [초밥, 밥 210g(1공기), 배합초, 식초 20g(1⅓큰술), 설탕 10g(2작...
# 3     [두부 곤약잡곡밥, 두부 110g(⅓모), 흰쌀 15g, 현미쌀 3g, 찹쌀 3g,...
# 4     [흑미밥, 쌀 90g, 검은 쌀 10g, 닭가슴살 삶기, 닭가슴살 40g(1/3개)...
# 5     [취나물밥, 밥 210g(1공기), 다진 쇠고기 20g(1⅓큰술), 취나물 20g(...
# 6     [잡곡밥, 잡곡밥 140g(2/3공기), 곰취쌈, 곰취 30g, 소금 약간, 해물채...
# 7     [단호박찰밥, 찹쌀 100g, 밤 30g(3개), 은행 20g(8알), 잣 10g(...
# 8     [영양밥, 찹쌀 100g, 흑미30g, 바지락 50g(16개), 강낭콩 15g(1큰...
# 9     [새우두부계란찜, 연두부 75g(3/4모), 칵테일새우 20g(5마리), 달걀 30...
# 10    [부추 콩가루 찜, 조선부추 50g, 날콩가루 7g(1⅓작은술), 양념장, 저염간장...
# 11    [연근 손질, 물 200ml(1컵), 식초 15g(1큰술), 연근 구기자 물김치, ...
# 12    [방울토마토 소박이, 방울토마토 150g(5개), 양파 10g(3×1cm), 부추 ...
# 13    [오이무침, 오이 70g(1/3개), 다진 땅콩 10g(1큰술), 순두부사과 소스,...
# 14    [북엇국, 북어채 25g(15개), 새우 10g(3마리), 사과 30g(1/5개),...
# 15    [닭육수, 닭 150g, 대파 15g(7cm), 마늘 10g(2쪽), 물 500ml...
# 16    [멸치육수, 양파 20g(1/6개), 멸치 15g(7마리), 다진 마늘 10g(2쪽...
# ...

# %%
for i in res:
    for j in i:
        if ',' in j:
            print(j)
        else:
# Out:
# 고구마 100g(2/3개), 설탕 2g(1/3작은술), 찹쌀가루 3g(2/3작은술), 물 200ml(1컵), 잣 8g(8알)
# 애호박 30g(1/6개), 표고버섯 20g(2개), 당근 5g(3×2×1cm)
# 누룽지 70g(1/3컵), 순두부 100g(1/4모), 달걀 50g(1개),참기름 3g(2/3작은술), 소금 약간, 참깨 약간, 흰후추 약간
# 식초 20g(1⅓큰술), 설탕 10g(2작은술), 소금 약간
# 달걀노른자 40g(달걀2개), 표고버섯 10g(1장), 새송이버섯 20g(3개), 새우 25g(4마리), 홍피망 10g(1/8개), 청피망 10g(1/8개), 양파 5g(5×1cm), 대두유 20g(1⅓큰술), 참기름 10g(2작은술), 식용유 약간
# 두부 110g(⅓모), 흰쌀 15g, 현미쌀 3g, 찹쌀 3g, 실곤약 3g
# 콩나물 15g(15개), 표고버섯 4g(1/2장), 애호박 10g(5×2×1cm), 고사리 15g(7줄기), 당근 15g(5×3×1cm), 소금 3g(2/3작은술), 소금 약간(나물데침)
# 초고추장 5g(1작은술), 플레인요거트 10g(2작은술), 참기름 2g(1/3작은술)
# 쌀 90g, 검은 쌀 10g
# 닭가슴살 40g(1/3개), 월계수 잎 2장, 후추 약간
# 숙주 20g(1/20봉지), 토란대 20g(5cm, 5개), 고사리 20g(10줄기)
# 달걀 50g(1개), 대파 10g(5cm), 들기름 5g(1작은술), 실고추약간, 소금약간
# 들깨가루 15g(1큰술), 고추기름 10g(2작은술), 꿀 8g(1⅔작은술), 저염간장 8g(1⅔작은술)
# 밥 210g(1공기), 다진 쇠고기 20g(1⅓큰술), 취나물 20g(8줄기), 다진 양파 5g(1작은술), 다진마늘 5g(1작은술), 간장 약간, 매실즙 3g(2/3작은술), 참기름 2g(1/3작은술), 참깨 5g(1작은술), 소금 약간
# ...
