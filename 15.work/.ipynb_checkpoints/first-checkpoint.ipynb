# %%
import pandas as pd

# %%
df = pd.read_excel(io='OJT.xls', 
                   sheet_name='공공데이터',
                   usecols='B:C',
                   names = ['RCP_PARTS_DTLS', '레시피명'])
df.head(20)
# Out:
#                                        RCP_PARTS_DTLS                레시피명
# 0   고구마죽\n고구마 100g(2/3개), 설탕 2g(1/3작은술), 찹쌀가루 3g(2...          칼륨 듬뿍 고구마죽
# 1   채소준비\n애호박 30g(1/6개), 표고버섯 20g(2개), 당근 5g(3×2×1...          누룽지 두부 계란죽
# 2   초밥\n밥 210g(1공기)\n배합초\n식초 20g(1⅓큰술), 설탕 10g(2작은...            오색지라시 스시
# 3   두부 곤약잡곡밥\n두부 110g(⅓모), 흰쌀 15g, 현미쌀 3g, 찹쌀 3g, ...        두부 곤약 나물 비빔밥
# 4   흑미밥\n쌀 90g, 검은 쌀 10g\n닭가슴살 삶기\n닭가슴살 40g(1/3개),...  저염 간장을 이용한 닭개장 비빔밥
# 5   취나물밥\n밥 210g(1공기), 다진 쇠고기 20g(1⅓큰술), 취나물 20g(8...    취나물 비빔밥 & 청국장 쌈장
# 6   잡곡밥\n잡곡밥 140g(2/3공기)\n곰취쌈\n곰취 30g, 소금 약간\n해물채소...    해물 채소장을 넣은 곰취 쌈밥
# 7   단호박찰밥\n찹쌀 100g, 밤 30g(3개), 은행 20g(8알), 잣 10g(1...             단호박 케일밥
# 8   영양밥\n찹쌀 100g, 흑미30g, 바지락 50g(16개), 강낭콩 15g(1큰술...             오색영양밥 롤
# 9   새우두부계란찜\n연두부 75g(3/4모), 칵테일새우 20g(5마리), 달걀 30g...           새우 두부 계란찜
# 10  부추 콩가루 찜\n조선부추 50g, 날콩가루 7g(1⅓작은술)\n양념장\n저염간장 ...            부추 콩가루 찜
# 11  연근 손질\n물 200ml(1컵), 식초 15g(1큰술)\n연근 구기자 물김치\n동...          연근 구기자 물김치
# ...

# %%
df[["0","1"]] = df["RCP_PARTS_DTLS"].str.split(pat = "\n", n=1, expand = True)
df.head(20)
# Out:
#                                        RCP_PARTS_DTLS                레시피명  \
# 0   고구마죽\n고구마 100g(2/3개), 설탕 2g(1/3작은술), 찹쌀가루 3g(2...          칼륨 듬뿍 고구마죽
# 1   채소준비\n애호박 30g(1/6개), 표고버섯 20g(2개), 당근 5g(3×2×1...          누룽지 두부 계란죽
# 2   초밥\n밥 210g(1공기)\n배합초\n식초 20g(1⅓큰술), 설탕 10g(2작은...            오색지라시 스시
# 3   두부 곤약잡곡밥\n두부 110g(⅓모), 흰쌀 15g, 현미쌀 3g, 찹쌀 3g, ...        두부 곤약 나물 비빔밥
# 4   흑미밥\n쌀 90g, 검은 쌀 10g\n닭가슴살 삶기\n닭가슴살 40g(1/3개),...  저염 간장을 이용한 닭개장 비빔밥
# 5   취나물밥\n밥 210g(1공기), 다진 쇠고기 20g(1⅓큰술), 취나물 20g(8...    취나물 비빔밥 & 청국장 쌈장
# 6   잡곡밥\n잡곡밥 140g(2/3공기)\n곰취쌈\n곰취 30g, 소금 약간\n해물채소...    해물 채소장을 넣은 곰취 쌈밥
# 7   단호박찰밥\n찹쌀 100g, 밤 30g(3개), 은행 20g(8알), 잣 10g(1...             단호박 케일밥
# 8   영양밥\n찹쌀 100g, 흑미30g, 바지락 50g(16개), 강낭콩 15g(1큰술...             오색영양밥 롤
# 9   새우두부계란찜\n연두부 75g(3/4모), 칵테일새우 20g(5마리), 달걀 30g...           새우 두부 계란찜
# 10  부추 콩가루 찜\n조선부추 50g, 날콩가루 7g(1⅓작은술)\n양념장\n저염간장 ...            부추 콩가루 찜
# 11  연근 손질\n물 200ml(1컵), 식초 15g(1큰술)\n연근 구기자 물김치\n동...          연근 구기자 물김치
# ...

# %%
df = df["RCP_PARTS_DTLS"].str.split(pat = "\n", n=1, expand = True)
res = res.drop(labels = "RCP_PARTS_DTLS", axis = "columns")
res = res.drop(labels = "레시피명", axis = "columns")
res.head(20)
# Out:
#             1                                                  2
# 0        고구마죽  고구마 100g(2/3개), 설탕 2g(1/3작은술), 찹쌀가루 3g(2/3작은술)...
# 1        채소준비  애호박 30g(1/6개), 표고버섯 20g(2개), 당근 5g(3×2×1cm)\n누...
# 2          초밥  밥 210g(1공기)\n배합초\n식초 20g(1⅓큰술), 설탕 10g(2작은술), ...
# 3    두부 곤약잡곡밥  두부 110g(⅓모), 흰쌀 15g, 현미쌀 3g, 찹쌀 3g, 실곤약 3g\n나물...
# 4         흑미밥  쌀 90g, 검은 쌀 10g\n닭가슴살 삶기\n닭가슴살 40g(1/3개), 월계수 ...
# 5        취나물밥  밥 210g(1공기), 다진 쇠고기 20g(1⅓큰술), 취나물 20g(8줄기), 다...
# 6         잡곡밥  잡곡밥 140g(2/3공기)\n곰취쌈\n곰취 30g, 소금 약간\n해물채소장\n조갯...
# 7       단호박찰밥  찹쌀 100g, 밤 30g(3개), 은행 20g(8알), 잣 10g(10알), 단호...
# 8         영양밥  찹쌀 100g, 흑미30g, 바지락 50g(16개), 강낭콩 15g(1큰술), 완두...
# 9     새우두부계란찜  연두부 75g(3/4모), 칵테일새우 20g(5마리), 달걀 30g(1/2개), 생...
# 10   부추 콩가루 찜  조선부추 50g, 날콩가루 7g(1⅓작은술)\n양념장\n저염간장 3g(2/3작은술)...
# 11      연근 손질  물 200ml(1컵), 식초 15g(1큰술)\n연근 구기자 물김치\n동치미국물 40...
# 12  방울토마토 소박이  방울토마토 150g(5개), 양파 10g(3×1cm), 부추 10g(5줄기)\n양념...
# ...

# %%
res[["2","3"]] = res["2"].str.split(pat = "\n", n=1, expand = True)
res.head(20)
# Out:
#             1                                                  2  \
# 0        고구마죽  고구마 100g(2/3개), 설탕 2g(1/3작은술), 찹쌀가루 3g(2/3작은술)...
# 1        채소준비        애호박 30g(1/6개), 표고버섯 20g(2개), 당근 5g(3×2×1cm)
# 2          초밥                                        밥 210g(1공기)
# 3    두부 곤약잡곡밥         두부 110g(⅓모), 흰쌀 15g, 현미쌀 3g, 찹쌀 3g, 실곤약 3g
# 4         흑미밥                                    쌀 90g, 검은 쌀 10g
# 5        취나물밥  밥 210g(1공기), 다진 쇠고기 20g(1⅓큰술), 취나물 20g(8줄기), 다...
# 6         잡곡밥                                    잡곡밥 140g(2/3공기)
# 7       단호박찰밥  찹쌀 100g, 밤 30g(3개), 은행 20g(8알), 잣 10g(10알), 단호...
# 8         영양밥  찹쌀 100g, 흑미30g, 바지락 50g(16개), 강낭콩 15g(1큰술), 완두...
# 9     새우두부계란찜  연두부 75g(3/4모), 칵테일새우 20g(5마리), 달걀 30g(1/2개), 생...
# 10   부추 콩가루 찜                           조선부추 50g, 날콩가루 7g(1⅓작은술)
# 11      연근 손질                           물 200ml(1컵), 식초 15g(1큰술)
# 12  방울토마토 소박이         방울토마토 150g(5개), 양파 10g(3×1cm), 부추 10g(5줄기)
# ...

# %%
res = res.stack().reset_index(level=2, drop=True)
res.head(20)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\multi.py:1555, in MultiIndex._get_level_number(self, level)
#    1554 try:
# -> 1555     level = self.names.index(level)
#    1556 except ValueError as err:
#
# ValueError: 2 is not in list
#
# The above exception was the direct cause of the following exception:
#
# IndexError                                Traceback (most recent call last)
# Cell In[74], line 1
# ----> 1 res = res.stack().reset_index(level=2, drop=True)
#       2 res.head(20)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
# ...

# %%
res[["3","4"]] = res["3"].str.split(pat = "\n", n=1, expand = True)
res.head(10)
# Out:
#           1                                                  2        3  \
# 0      고구마죽  고구마 100g(2/3개), 설탕 2g(1/3작은술), 찹쌀가루 3g(2/3작은술)...     None
# 1      채소준비        애호박 30g(1/6개), 표고버섯 20g(2개), 당근 5g(3×2×1cm)    누룽지 죽
# 2        초밥                                        밥 210g(1공기)      배합초
# 3  두부 곤약잡곡밥         두부 110g(⅓모), 흰쌀 15g, 현미쌀 3g, 찹쌀 3g, 실곤약 3g     나물준비
# 4       흑미밥                                    쌀 90g, 검은 쌀 10g  닭가슴살 삶기
# 5      취나물밥  밥 210g(1공기), 다진 쇠고기 20g(1⅓큰술), 취나물 20g(8줄기), 다...    청국장쌈장
# 6       잡곡밥                                    잡곡밥 140g(2/3공기)      곰취쌈
# 7     단호박찰밥  찹쌀 100g, 밤 30g(3개), 은행 20g(8알), 잣 10g(10알), 단호...     케일소스
# 8       영양밥  찹쌀 100g, 흑미30g, 바지락 50g(16개), 강낭콩 15g(1큰술), 완두...     오색준비
# 9   새우두부계란찜  연두부 75g(3/4모), 칵테일새우 20g(5마리), 달걀 30g(1/2개), 생...       고명
#
#                                                    4
# 0                                               None
# 1  누룽지 70g(1/3컵), 순두부 100g(1/4모), 달걀 50g(1개),참기름 ...
# ...
