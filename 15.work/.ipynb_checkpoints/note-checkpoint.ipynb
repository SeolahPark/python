# %%
import pandas as pd

# %%
df = pd.read_excel(io='OJT.xls', 
                   sheet_name='공공데이터',
                   usecols='B:C')

# %%
column_name = ['레시피명', '단계', '재료', '함량', '단위' ,'목측량']

# %%
df
# Out:
#                                          RCP_PARTS_DTLS              RCP_NM
# 0     고구마죽\n고구마 100g(2/3개), 설탕 2g(1/3작은술), 찹쌀가루 3g(2...          칼륨 듬뿍 고구마죽
# 1     채소준비\n애호박 30g(1/6개), 표고버섯 20g(2개), 당근 5g(3×2×1...          누룽지 두부 계란죽
# 2     초밥\n밥 210g(1공기)\n배합초\n식초 20g(1⅓큰술), 설탕 10g(2작은...            오색지라시 스시
# 3     두부 곤약잡곡밥\n두부 110g(⅓모), 흰쌀 15g, 현미쌀 3g, 찹쌀 3g, ...        두부 곤약 나물 비빔밥
# 4     흑미밥\n쌀 90g, 검은 쌀 10g\n닭가슴살 삶기\n닭가슴살 40g(1/3개),...  저염 간장을 이용한 닭개장 비빔밥
# ...                                                 ...                 ...
# 1353  [ 2인분 ] 마늘(4쪽), 토마토(2개), 양파(1개), 월계수잎(2장), 육수용...             양파토마토스튜
# 1354  [ 2인분 ] 황금팽이버섯(400g), 양파( 개), 상추(2장), 깻잎(2장), ...           황금팽이 비빔국수
# 1355  [ 4인분 ] 미역 줄기(1팩=300g), 양파(½개), 맛살(135g), 건새우(...            맛살 미역줄기전
# 1356  [ 2인분 ] 새송이버섯(1개), 방울토마토(200g), 오징어(1마리), 칵테일새...       해산물샐러드와 미나리소스
# 1357  [ 2인분 ] 토마토(2개), 양파(¼개), 감자(¼개), 노랑 파프리카(¼개), ...        매운요거트 토마토샐러드
#
# [1358 rows x 2 columns]

# %%
s1 = pd.core.series.Series(df.RCP_PARTS_DTLS)

# %%
s1
# Out:
# 0       고구마죽\n고구마 100g(2/3개), 설탕 2g(1/3작은술), 찹쌀가루 3g(2...
# 1       채소준비\n애호박 30g(1/6개), 표고버섯 20g(2개), 당근 5g(3×2×1...
# 2       초밥\n밥 210g(1공기)\n배합초\n식초 20g(1⅓큰술), 설탕 10g(2작은...
# 3       두부 곤약잡곡밥\n두부 110g(⅓모), 흰쌀 15g, 현미쌀 3g, 찹쌀 3g, ...
# 4       흑미밥\n쌀 90g, 검은 쌀 10g\n닭가슴살 삶기\n닭가슴살 40g(1/3개),...
#                               ...
# 1353    [ 2인분 ] 마늘(4쪽), 토마토(2개), 양파(1개), 월계수잎(2장), 육수용...
# 1354    [ 2인분 ] 황금팽이버섯(400g), 양파( 개), 상추(2장), 깻잎(2장), ...
# 1355    [ 4인분 ] 미역 줄기(1팩=300g), 양파(½개), 맛살(135g), 건새우(...
# 1356    [ 2인분 ] 새송이버섯(1개), 방울토마토(200g), 오징어(1마리), 칵테일새...
# 1357    [ 2인분 ] 토마토(2개), 양파(¼개), 감자(¼개), 노랑 파프리카(¼개), ...
# Name: RCP_PARTS_DTLS, Length: 1358, dtype: object

# %%
s2 = pd.core.series.Series(df.RCP_NM)

# %%
s2
# Out:
# 0               칼륨 듬뿍 고구마죽
# 1               누룽지 두부 계란죽
# 2                 오색지라시 스시
# 3             두부 곤약 나물 비빔밥
# 4       저염 간장을 이용한 닭개장 비빔밥
#                ...
# 1353               양파토마토스튜
# 1354             황금팽이 비빔국수
# 1355              맛살 미역줄기전
# 1356         해산물샐러드와 미나리소스
# 1357          매운요거트 토마토샐러드
# Name: RCP_NM, Length: 1358, dtype: object

# %%
df['단계'] = df.RCP_PARTS_DTLS.str.split('\n').str[0]

# %%
df
# Out:
#                                          RCP_PARTS_DTLS              RCP_NM  \
# 0     고구마죽\n고구마 100g(2/3개), 설탕 2g(1/3작은술), 찹쌀가루 3g(2...          칼륨 듬뿍 고구마죽
# 1     채소준비\n애호박 30g(1/6개), 표고버섯 20g(2개), 당근 5g(3×2×1...          누룽지 두부 계란죽
# 2     초밥\n밥 210g(1공기)\n배합초\n식초 20g(1⅓큰술), 설탕 10g(2작은...            오색지라시 스시
# 3     두부 곤약잡곡밥\n두부 110g(⅓모), 흰쌀 15g, 현미쌀 3g, 찹쌀 3g, ...        두부 곤약 나물 비빔밥
# 4     흑미밥\n쌀 90g, 검은 쌀 10g\n닭가슴살 삶기\n닭가슴살 40g(1/3개),...  저염 간장을 이용한 닭개장 비빔밥
# ...                                                 ...                 ...
# 1353  [ 2인분 ] 마늘(4쪽), 토마토(2개), 양파(1개), 월계수잎(2장), 육수용...             양파토마토스튜
# 1354  [ 2인분 ] 황금팽이버섯(400g), 양파( 개), 상추(2장), 깻잎(2장), ...           황금팽이 비빔국수
# 1355  [ 4인분 ] 미역 줄기(1팩=300g), 양파(½개), 맛살(135g), 건새우(...            맛살 미역줄기전
# 1356  [ 2인분 ] 새송이버섯(1개), 방울토마토(200g), 오징어(1마리), 칵테일새...       해산물샐러드와 미나리소스
# 1357  [ 2인분 ] 토마토(2개), 양파(¼개), 감자(¼개), 노랑 파프리카(¼개), ...        매운요거트 토마토샐러드
#
# ...

# %%
df['레시피명'] = df.RCP_NM

# %%
df.drop('RCP_NM', axis='columns')
df.drop('단계', axis='columns')
# Out:
#                                          RCP_PARTS_DTLS              RCP_NM  \
# 0     고구마죽\n고구마 100g(2/3개), 설탕 2g(1/3작은술), 찹쌀가루 3g(2...          칼륨 듬뿍 고구마죽
# 1     채소준비\n애호박 30g(1/6개), 표고버섯 20g(2개), 당근 5g(3×2×1...          누룽지 두부 계란죽
# 2     초밥\n밥 210g(1공기)\n배합초\n식초 20g(1⅓큰술), 설탕 10g(2작은...            오색지라시 스시
# 3     두부 곤약잡곡밥\n두부 110g(⅓모), 흰쌀 15g, 현미쌀 3g, 찹쌀 3g, ...        두부 곤약 나물 비빔밥
# 4     흑미밥\n쌀 90g, 검은 쌀 10g\n닭가슴살 삶기\n닭가슴살 40g(1/3개),...  저염 간장을 이용한 닭개장 비빔밥
# ...                                                 ...                 ...
# 1353  [ 2인분 ] 마늘(4쪽), 토마토(2개), 양파(1개), 월계수잎(2장), 육수용...             양파토마토스튜
# 1354  [ 2인분 ] 황금팽이버섯(400g), 양파( 개), 상추(2장), 깻잎(2장), ...           황금팽이 비빔국수
# 1355  [ 4인분 ] 미역 줄기(1팩=300g), 양파(½개), 맛살(135g), 건새우(...            맛살 미역줄기전
# 1356  [ 2인분 ] 새송이버섯(1개), 방울토마토(200g), 오징어(1마리), 칵테일새...       해산물샐러드와 미나리소스
# 1357  [ 2인분 ] 토마토(2개), 양파(¼개), 감자(¼개), 노랑 파프리카(¼개), ...        매운요거트 토마토샐러드
#
#                     레시피명
# 0             칼륨 듬뿍 고구마죽
# ...

# %%
# ㅠㅠㅠㅠㅠ어려웡~!!~!~!~!~!~!

# %%
newdf = df.RCP_PARTS_DTLS.str.split(pat="\n", expand = True).head()

# %%
num = 2

for i in range(num):
    df_notnull = newdf[newdf[i].notnull()] 
    num += 2
# Out:
# NOTE: Enter 'c' at the ipdb>  prompt to continue execution.
# > <string>(1)<module>()
#
# ipdb> 1
# 1
# ipdb> 2
# 2
# ipdb> 3
# 3
# ipdb> 4
# 4
# ipdb> 5
# 5
# ipdb> er
# *** NameError: name 'er' is not defined
# ipdb> 6
# 6
# ipdb> 8
# 8
# ipdb> 9
# 9
# ipdb> 0
# 0
# ipdb> 2
# 2
# ipdb> 42624625
# 42624625

# %%
df_notnull
# Out:
#          0                                                  1        2   \
# 0      고구마죽  고구마 100g(2/3개), 설탕 2g(1/3작은술), 찹쌀가루 3g(2/3작은술)...     None
# 1      채소준비        애호박 30g(1/6개), 표고버섯 20g(2개), 당근 5g(3×2×1cm)    누룽지 죽
# 2        초밥                                        밥 210g(1공기)      배합초
# 3  두부 곤약잡곡밥         두부 110g(⅓모), 흰쌀 15g, 현미쌀 3g, 찹쌀 3g, 실곤약 3g     나물준비
# 4       흑미밥                                    쌀 90g, 검은 쌀 10g  닭가슴살 삶기
#
#                                                   3         4   \
# 0                                               None      None
# 1  누룽지 70g(1/3컵), 순두부 100g(1/4모), 달걀 50g(1개),참기름 ...      None
# 2                  식초 20g(1⅓큰술), 설탕 10g(2작은술), 소금 약간     오색지라시
# 3  콩나물 15g(15개), 표고버섯 4g(1/2장), 애호박 10g(5×2×1cm),...  비빔고추장 소스
# 4                    닭가슴살 40g(1/3개), 월계수 잎 2장, 후추 약간      나물준비
#
#                                                   5     6   \
# 0                                               None  None
# ...

# %%
newdf[0]
# Out:
# 0        고구마죽
# 1        채소준비
# 2          초밥
# 3    두부 곤약잡곡밥
# 4         흑미밥
# Name: 0, dtype: object
